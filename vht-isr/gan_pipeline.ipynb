# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN
# Out:
# /content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN

# %%
# !rm -rf /content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN/superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000

# %%
# !python main_train_kdsrgan.py
# Out:
# export CUDA_VISIBLE_DEVICES=0
# LogHandlers setup!
# 24-08-17 05:51:13.666 :   task: 0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000
#   model: gan
#   gpu_ids: [0]
#   scale: 2
#   n_channels: 3
#   sigma: [0, 50]
#   sigma_test: 0
#   merge_bn: False
#   merge_bn_startpoint: 400000
#   path:[
#     root: superresolution
#     pretrained_netG: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/models/5630_G.pth
#     pretrained_netD: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/models/5630_D.pth
#     task: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000
#     log: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000
#     options: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/options
#     models: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/models
#     images: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/images
#   ]
#   datasets:[
# ...
