# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN
# Out:
# /content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN

# %%
# !rm -rf "/content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN/superresolution/"

# %%
# !python main_train_kdsrgan.py
# Out:
# export CUDA_VISIBLE_DEVICES=0
# LogHandlers setup!
# 24-08-18 13:38:21.869 :   task: 0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000
#   model: gan
#   gpu_ids: [0]
#   scale: 2
#   n_channels: 3
#   sigma: [0, 50]
#   sigma_test: 0
#   merge_bn: False
#   merge_bn_startpoint: 400000
#   path:[
#     root: superresolution
#     pretrained_netG: None
#     pretrained_netD: None
#     task: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000
#     log: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000
#     options: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/options
#     models: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/models
#     images: superresolution/0529msrresnet_gan_kd_x2_s4_for nc128 le-4 IR 20000/images
#   ]
#   datasets:[
#     train:[
#       name: train_dataset
#       dataset_type: sr
#       dataroot_H: /content/drive/MyDrive/DATA/VHT-DATA/data/train/HD
#       dataroot_L: /content/drive/MyDrive/DATA/VHT-DATA/data/train/SD
#       H_size: 96
#       dataloader_shuffle: True
#       dataloader_num_workers: 8
#       dataloader_batch_size: 32
#       phase: train
#       scale: 2
#       n_channels: 3
#     ]
#     test:[
#       name: test_dataset
#       dataset_type: sr
#       dataroot_H: /content/drive/MyDrive/DATA/VHT-DATA/data/val/HD
#       dataroot_L: /content/drive/MyDrive/DATA/VHT-DATA/data/val/SD
#       phase: test
#       scale: 2
#       n_channels: 3
#     ]
#   ]
#   netG:[
#     net_type: msrresnet0
#     en_net_type: D_msrresnet0
#     enhance: no_enhance
#     in_nc: 3
#     out_nc: 3
#     nc: 64
#     nb: 16
#     gc: 32
#     ng: 2
#     reduction: 16
#     act_mode: R
#     upsample_mode: upconv
#     downsample_mode: strideconv
#     init_type: orthogonal
#     init_bn_type: uniform
#     init_gain: 0.2
#     scale: 2
#   ]
#   netD:[
#     net_type: discriminator_vgg_96
#     in_nc: 3
#     act_mode: BL
#     base_nc: 64
#     init_type: orthogonal
#     init_bn_type: uniform
#     init_gain: 0.2
#   ]
#   train:[
#     G_lossfn_type: l1
#     G_lossfn_weight: 0.01
#     F_lossfn_type: l1
#     F_lossfn_weight: 1
#     gan_type: ragan
#     D_lossfn_weight: 0.005
#     D_init_iters: 0
#     G_optimizer_type: adam
#     G_optimizer_lr: 0.0001
#     G_optimizer_wd: 0
#     D_optimizer_type: adam
#     D_optimizer_lr: 0.0001
#     D_optimizer_wd: 0
#     G_scheduler_type: MultiStepLR
#     G_scheduler_milestones: [100000, 200000, 1200000, 2000000]
#     G_scheduler_gamma: 0.5
#     D_scheduler_type: MultiStepLR
#     D_scheduler_milestones: [100000, 200000, 1200000, 2000000]
#     D_scheduler_gamma: 0.5
#     checkpoint_test: 1000
#     checkpoint_save: 1000
#     checkpoint_print: 100
#   ]
#   opt_path: options/train_kdsrgan.json
#   is_train: True
#
# 24-08-18 13:38:21.872 : Random seed: 7607
# Dataset [DatasetSR - train_dataset] is created.
# 24-08-18 13:38:21.881 : Number of train images: 99, iters: 4
# Dataset [DatasetSR - test_dataset] is created.
# Initialization method [orthogonal + uniform], gain is [0.20]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Initialization method [orthogonal + uniform], gain is [0.20]
# 24-08-18 13:38:25.934 :
# Networks name: D_msrresnet0
# Params number: 312736
# Net structure:
# D_msrresnet0(
#   (KD): KDB(
#     (c1_d): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=64)
#       (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (c1_r): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (c2_d): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=64)
#       (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (c2_r): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (c3_d): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=64)
#       (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (c3_r): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (c4): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#       (1): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (act): LeakyReLU(negative_slope=0.05, inplace=True)
#     (c5): Sequential(
#       (0): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), groups=128)
#       (1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (esa): ESA(
#       (conv1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), groups=64)
#         (1): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_f): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), groups=16)
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv_max): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv2): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16)
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv3): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv3_): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16)
#         (1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (conv4): Sequential(
#         (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), groups=16)
#         (1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (sigmoid): Sigmoid()
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (head): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (body): Identity +
#   |Sequential(
#   |  (0): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (1): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (2): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (3): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (4): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (5): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (6): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (7): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (8): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (9): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (10): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (11): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (12): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (13): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (14): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (15): ResBlock(
#   |    (res): Sequential(
#   |      (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |      (2): ReLU(inplace=True)
#   |      (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#   |      (4): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#   |    )
#   |  )
#   |  (16): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   |)
#   (tail): Sequential(
#     (0): Upsample(scale_factor=2.0, mode='nearest')
#     (1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (copress): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
# )
#
# Networks name: Discriminator_VGG_96
# Params number: 14143881
# Net structure:
# Discriminator_VGG_96(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(64, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (2): BatchNorm2d(64, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.2, inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (9): LeakyReLU(negative_slope=0.2, inplace=True)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(256, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (12): LeakyReLU(negative_slope=0.2, inplace=True)
#     (13): Conv2d(256, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (14): BatchNorm2d(256, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (15): LeakyReLU(negative_slope=0.2, inplace=True)
#     (16): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): BatchNorm2d(512, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (18): LeakyReLU(negative_slope=0.2, inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (20): BatchNorm2d(512, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (21): LeakyReLU(negative_slope=0.2, inplace=True)
#     (22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): BatchNorm2d(512, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (24): LeakyReLU(negative_slope=0.2, inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (26): BatchNorm2d(512, eps=0.0001, momentum=0.9, affine=True, track_running_stats=True)
#     (27): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4608, out_features=100, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=100, out_features=1, bias=True)
#   )
# )
#
# Networks name: VGGFeatureExtractor
# Params number: 20024384
# Net structure:
# VGGFeatureExtractor(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
#
# 24-08-18 13:38:26.089 :
#  |  mean  |  min   |  max   |  std   || param_name
#  |  0.003 | -0.081 |  0.075 |  0.032 || KD.c1_d.0.weight
#  |  0.000 | -0.008 |  0.010 |  0.004 || KD.c1_d.0.bias
#  | -0.000 | -0.086 |  0.078 |  0.025 || KD.c1_d.1.weight
#  | -0.001 | -0.005 |  0.005 |  0.002 || KD.c1_d.1.bias
#  |  0.000 | -0.078 |  0.080 |  0.025 || KD.c1_r.0.weight
#  | -0.001 | -0.016 |  0.017 |  0.008 || KD.c1_r.0.bias
#  | -0.001 | -0.093 |  0.086 |  0.025 || KD.c1_r.1.weight
#  |  0.007 | -0.017 |  0.043 |  0.012 || KD.c1_r.1.bias
#  |  0.009 | -0.061 |  0.064 |  0.030 || KD.c2_d.0.weight
#  | -0.001 | -0.011 |  0.006 |  0.003 || KD.c2_d.0.bias
#  |  0.001 | -0.075 |  0.081 |  0.025 || KD.c2_d.1.weight
#  | -0.001 | -0.004 |  0.009 |  0.002 || KD.c2_d.1.bias
#  |  0.001 | -0.074 |  0.069 |  0.025 || KD.c2_r.0.weight
#  |  0.000 | -0.016 |  0.015 |  0.007 || KD.c2_r.0.bias
#  |  0.000 | -0.084 |  0.092 |  0.025 || KD.c2_r.1.weight
#  |  0.002 | -0.017 |  0.025 |  0.009 || KD.c2_r.1.bias
#  | -0.001 | -0.076 |  0.057 |  0.031 || KD.c3_d.0.weight
#  |  0.000 | -0.008 |  0.008 |  0.004 || KD.c3_d.0.bias
#  | -0.001 | -0.089 |  0.081 |  0.025 || KD.c3_d.1.weight
#  | -0.001 | -0.003 |  0.003 |  0.001 || KD.c3_d.1.bias
#  |  0.000 | -0.073 |  0.075 |  0.025 || KD.c3_r.0.weight
#  |  0.000 | -0.011 |  0.015 |  0.007 || KD.c3_r.0.bias
#  | -0.001 | -0.102 |  0.081 |  0.025 || KD.c3_r.1.weight
#  |  0.002 | -0.017 |  0.026 |  0.009 || KD.c3_r.1.bias
#  | -0.001 | -0.074 |  0.092 |  0.029 || KD.c4.0.weight
#  | -0.000 | -0.008 |  0.008 |  0.004 || KD.c4.0.bias
#  |  0.001 | -0.074 |  0.095 |  0.025 || KD.c4.1.weight
#  | -0.000 | -0.009 |  0.009 |  0.004 || KD.c4.1.bias
#  |  0.001 | -0.033 |  0.044 |  0.011 || KD.c5.0.weight
#  |  0.000 | -0.002 |  0.003 |  0.001 || KD.c5.0.bias
#  | -0.000 | -0.052 |  0.056 |  0.015 || KD.c5.1.weight
#  | -0.000 | -0.007 |  0.002 |  0.001 || KD.c5.1.bias
#  |  0.000 | -0.072 |  0.057 |  0.025 || KD.esa.conv1.0.weight
#  |  0.000 | -0.001 |  0.001 |  0.001 || KD.esa.conv1.0.bias
#  | -0.001 | -0.063 |  0.082 |  0.025 || KD.esa.conv1.1.weight
#  |  0.000 | -0.006 |  0.010 |  0.005 || KD.esa.conv1.1.bias
#  | -0.015 | -0.116 |  0.096 |  0.050 || KD.esa.conv_f.0.weight
#  |  0.006 | -0.028 |  0.029 |  0.024 || KD.esa.conv_f.0.bias
#  |  0.008 | -0.431 |  0.418 |  0.236 || KD.esa.conv_f.1.weight
#  |  0.002 | -0.010 |  0.021 |  0.011 || KD.esa.conv_f.1.bias
#  | -0.004 | -0.136 |  0.105 |  0.050 || KD.esa.conv_max.0.weight
#  |  0.000 | -0.000 |  0.000 |  0.000 || KD.esa.conv_max.0.bias
#  | -0.004 | -0.152 |  0.109 |  0.050 || KD.esa.conv_max.1.weight
#  | -0.000 | -0.000 |  0.000 |  0.000 || KD.esa.conv_max.1.bias
#  | -0.007 | -0.123 |  0.104 |  0.050 || KD.esa.conv2.0.weight
#  |  0.000 | -0.000 |  0.000 |  0.000 || KD.esa.conv2.0.bias
#  | -0.001 | -0.146 |  0.113 |  0.050 || KD.esa.conv2.1.weight
#  | -0.000 | -0.000 |  0.000 |  0.000 || KD.esa.conv2.1.bias
#  |  0.008 | -0.094 |  0.122 |  0.050 || KD.esa.conv3.0.weight
#  |  0.000 | -0.000 |  0.000 |  0.000 || KD.esa.conv3.0.bias
#  | -0.005 | -0.127 |  0.104 |  0.050 || KD.esa.conv3.1.weight
#  | -0.000 | -0.000 | -0.000 |  0.000 || KD.esa.conv3.1.bias
#  |  0.002 | -0.159 |  0.112 |  0.050 || KD.esa.conv3_.0.weight
#  | -0.002 | -0.016 |  0.012 |  0.008 || KD.esa.conv3_.0.bias
#  |  0.001 | -0.126 |  0.126 |  0.050 || KD.esa.conv3_.1.weight
#  |  0.002 | -0.010 |  0.021 |  0.011 || KD.esa.conv3_.1.bias
#  |  0.027 | -0.071 |  0.109 |  0.050 || KD.esa.conv4.0.weight
#  |  0.007 | -0.011 |  0.022 |  0.011 || KD.esa.conv4.0.bias
#  | -0.006 | -0.091 |  0.073 |  0.027 || KD.esa.conv4.1.weight
#  | -0.033 | -0.064 | -0.005 |  0.018 || KD.esa.conv4.1.bias
#  |  0.000 | -0.411 |  0.447 |  0.071 || head.weight
#  | -0.000 | -0.044 |  0.045 |  0.017 || head.bias
#  |  0.024 | -0.363 |  0.328 |  0.099 || body.sub.0.res.0.weight
#  | -0.001 | -0.059 |  0.036 |  0.018 || body.sub.0.res.0.bias
#  |  0.001 | -0.290 |  0.304 |  0.062 || body.sub.0.res.1.weight
#  |  0.005 | -0.066 |  0.046 |  0.021 || body.sub.0.res.1.bias
#  |  0.002 | -0.309 |  0.332 |  0.079 || body.sub.0.res.3.weight
#  |  0.000 | -0.009 |  0.014 |  0.004 || body.sub.0.res.3.bias
#  | -0.001 | -0.247 |  0.199 |  0.048 || body.sub.0.res.4.weight
#  | -0.000 | -0.029 |  0.035 |  0.011 || body.sub.0.res.4.bias
#  |  0.006 | -0.409 |  0.496 |  0.146 || body.sub.1.res.0.weight
#  | -0.002 | -0.031 |  0.030 |  0.013 || body.sub.1.res.0.bias
#  | -0.003 | -0.393 |  0.454 |  0.087 || body.sub.1.res.1.weight
#  |  0.011 | -0.059 |  0.067 |  0.025 || body.sub.1.res.1.bias
#  | -0.007 | -0.390 |  0.559 |  0.133 || body.sub.1.res.3.weight
#  | -0.000 | -0.021 |  0.013 |  0.005 || body.sub.1.res.3.bias
#  |  0.000 | -0.390 |  0.352 |  0.064 || body.sub.1.res.4.weight
#  | -0.001 | -0.041 |  0.030 |  0.011 || body.sub.1.res.4.bias
#  | -0.009 | -0.481 |  0.507 |  0.126 || body.sub.2.res.0.weight
#  | -0.001 | -0.032 |  0.022 |  0.013 || body.sub.2.res.0.bias
#  | -0.001 | -0.801 |  0.854 |  0.094 || body.sub.2.res.1.weight
#  |  0.009 | -0.073 |  0.070 |  0.025 || body.sub.2.res.1.bias
#  |  0.012 | -0.456 |  0.622 |  0.142 || body.sub.2.res.3.weight
#  | -0.001 | -0.023 |  0.016 |  0.006 || body.sub.2.res.3.bias
#  | -0.003 | -0.642 |  0.547 |  0.079 || body.sub.2.res.4.weight
#  |  0.000 | -0.041 |  0.025 |  0.011 || body.sub.2.res.4.bias
#  |  0.002 | -0.679 |  0.497 |  0.144 || body.sub.3.res.0.weight
#  |  0.002 | -0.040 |  0.028 |  0.012 || body.sub.3.res.0.bias
#  | -0.002 | -0.733 |  0.620 |  0.100 || body.sub.3.res.1.weight
#  |  0.009 | -0.049 |  0.050 |  0.021 || body.sub.3.res.1.bias
#  | -0.003 | -0.481 |  0.522 |  0.154 || body.sub.3.res.3.weight
#  | -0.000 | -0.014 |  0.014 |  0.006 || body.sub.3.res.3.bias
#  |  0.001 | -0.374 |  0.462 |  0.078 || body.sub.3.res.4.weight
#  |  0.000 | -0.037 |  0.022 |  0.009 || body.sub.3.res.4.bias
#  |  0.001 | -0.487 |  0.525 |  0.141 || body.sub.4.res.0.weight
#  |  0.002 | -0.028 |  0.051 |  0.015 || body.sub.4.res.0.bias
#  |  0.009 | -0.411 |  0.578 |  0.094 || body.sub.4.res.1.weight
#  |  0.016 | -0.058 |  0.120 |  0.030 || body.sub.4.res.1.bias
#  | -0.014 | -0.395 |  0.566 |  0.132 || body.sub.4.res.3.weight
#  |  0.003 | -0.021 |  0.035 |  0.008 || body.sub.4.res.3.bias
#  |  0.001 | -0.618 |  0.450 |  0.071 || body.sub.4.res.4.weight
#  | -0.000 | -0.035 |  0.022 |  0.009 || body.sub.4.res.4.bias
#  | -0.000 | -0.414 |  0.486 |  0.137 || body.sub.5.res.0.weight
#  |  0.003 | -0.037 |  0.031 |  0.012 || body.sub.5.res.0.bias
#  |  0.001 | -0.577 |  0.601 |  0.094 || body.sub.5.res.1.weight
#  |  0.013 | -0.047 |  0.063 |  0.026 || body.sub.5.res.1.bias
#  | -0.012 | -0.654 |  0.412 |  0.137 || body.sub.5.res.3.weight
#  |  0.000 | -0.027 |  0.016 |  0.008 || body.sub.5.res.3.bias
#  |  0.001 | -0.345 |  0.288 |  0.066 || body.sub.5.res.4.weight
#  | -0.001 | -0.031 |  0.025 |  0.009 || body.sub.5.res.4.bias
#  | -0.000 | -0.634 |  0.500 |  0.150 || body.sub.6.res.0.weight
#  |  0.001 | -0.030 |  0.042 |  0.014 || body.sub.6.res.0.bias
#  |  0.002 | -0.419 |  0.578 |  0.096 || body.sub.6.res.1.weight
#  |  0.006 | -0.044 |  0.053 |  0.024 || body.sub.6.res.1.bias
#  |  0.003 | -0.662 |  0.561 |  0.147 || body.sub.6.res.3.weight
#  | -0.001 | -0.019 |  0.026 |  0.008 || body.sub.6.res.3.bias
#  |  0.001 | -0.328 |  0.366 |  0.072 || body.sub.6.res.4.weight
#  | -0.001 | -0.031 |  0.036 |  0.010 || body.sub.6.res.4.bias
#  |  0.000 | -0.375 |  0.338 |  0.134 || body.sub.7.res.0.weight
#  |  0.002 | -0.036 |  0.026 |  0.015 || body.sub.7.res.0.bias
#  |  0.002 | -0.442 |  0.522 |  0.080 || body.sub.7.res.1.weight
#  |  0.014 | -0.061 |  0.085 |  0.032 || body.sub.7.res.1.bias
#  |  0.011 | -0.383 |  0.411 |  0.126 || body.sub.7.res.3.weight
#  |  0.000 | -0.023 |  0.027 |  0.007 || body.sub.7.res.3.bias
#  | -0.001 | -0.268 |  0.267 |  0.056 || body.sub.7.res.4.weight
#  | -0.001 | -0.029 |  0.041 |  0.009 || body.sub.7.res.4.bias
#  | -0.004 | -0.542 |  0.414 |  0.169 || body.sub.8.res.0.weight
#  | -0.000 | -0.059 |  0.030 |  0.015 || body.sub.8.res.0.bias
#  |  0.003 | -0.446 |  0.422 |  0.093 || body.sub.8.res.1.weight
#  |  0.014 | -0.050 |  0.095 |  0.029 || body.sub.8.res.1.bias
#  | -0.032 | -0.461 |  0.501 |  0.144 || body.sub.8.res.3.weight
#  |  0.000 | -0.022 |  0.014 |  0.006 || body.sub.8.res.3.bias
#  | -0.000 | -0.334 |  0.312 |  0.075 || body.sub.8.res.4.weight
#  | -0.001 | -0.029 |  0.048 |  0.010 || body.sub.8.res.4.bias
#  | -0.016 | -0.449 |  0.392 |  0.147 || body.sub.9.res.0.weight
#  |  0.002 | -0.031 |  0.055 |  0.014 || body.sub.9.res.0.bias
#  |  0.003 | -0.497 |  0.515 |  0.094 || body.sub.9.res.1.weight
#  |  0.010 | -0.046 |  0.077 |  0.023 || body.sub.9.res.1.bias
#  |  0.005 | -0.498 |  0.425 |  0.144 || body.sub.9.res.3.weight
#  | -0.000 | -0.016 |  0.022 |  0.006 || body.sub.9.res.3.bias
#  |  0.001 | -0.394 |  0.390 |  0.075 || body.sub.9.res.4.weight
#  | -0.001 | -0.033 |  0.047 |  0.010 || body.sub.9.res.4.bias
#  | -0.017 | -0.547 |  0.458 |  0.158 || body.sub.10.res.0.weight
#  |  0.000 | -0.035 |  0.038 |  0.016 || body.sub.10.res.0.bias
#  | -0.001 | -0.486 |  0.424 |  0.090 || body.sub.10.res.1.weight
#  |  0.015 | -0.069 |  0.111 |  0.034 || body.sub.10.res.1.bias
#  |  0.011 | -0.358 |  0.479 |  0.134 || body.sub.10.res.3.weight
#  | -0.001 | -0.021 |  0.026 |  0.009 || body.sub.10.res.3.bias
#  | -0.000 | -0.341 |  0.341 |  0.072 || body.sub.10.res.4.weight
#  | -0.001 | -0.035 |  0.046 |  0.010 || body.sub.10.res.4.bias
#  | -0.006 | -0.709 |  0.683 |  0.161 || body.sub.11.res.0.weight
#  |  0.002 | -0.034 |  0.038 |  0.016 || body.sub.11.res.0.bias
#  | -0.002 | -0.707 |  0.626 |  0.097 || body.sub.11.res.1.weight
#  |  0.007 | -0.070 |  0.058 |  0.026 || body.sub.11.res.1.bias
#  |  0.013 | -0.768 |  0.558 |  0.151 || body.sub.11.res.3.weight
#  | -0.001 | -0.038 |  0.014 |  0.008 || body.sub.11.res.3.bias
#  | -0.000 | -0.499 |  0.473 |  0.083 || body.sub.11.res.4.weight
#  | -0.001 | -0.031 |  0.046 |  0.010 || body.sub.11.res.4.bias
#  | -0.003 | -0.496 |  0.450 |  0.148 || body.sub.12.res.0.weight
#  | -0.003 | -0.042 |  0.031 |  0.016 || body.sub.12.res.0.bias
#  |  0.007 | -0.356 |  0.359 |  0.090 || body.sub.12.res.1.weight
#  |  0.001 | -0.105 |  0.074 |  0.029 || body.sub.12.res.1.bias
#  |  0.005 | -0.360 |  0.396 |  0.139 || body.sub.12.res.3.weight
#  | -0.000 | -0.020 |  0.018 |  0.009 || body.sub.12.res.3.bias
#  |  0.002 | -0.334 |  0.317 |  0.075 || body.sub.12.res.4.weight
#  | -0.001 | -0.030 |  0.044 |  0.010 || body.sub.12.res.4.bias
#  | -0.026 | -0.370 |  0.327 |  0.139 || body.sub.13.res.0.weight
#  | -0.005 | -0.034 |  0.033 |  0.015 || body.sub.13.res.0.bias
#  | -0.001 | -0.368 |  0.467 |  0.085 || body.sub.13.res.1.weight
#  |  0.009 | -0.065 |  0.080 |  0.030 || body.sub.13.res.1.bias
#  | -0.022 | -0.406 |  0.455 |  0.134 || body.sub.13.res.3.weight
#  |  0.001 | -0.027 |  0.021 |  0.009 || body.sub.13.res.3.bias
#  | -0.000 | -0.297 |  0.261 |  0.069 || body.sub.13.res.4.weight
#  | -0.001 | -0.031 |  0.043 |  0.010 || body.sub.13.res.4.bias
#  | -0.042 | -0.451 |  0.357 |  0.150 || body.sub.14.res.0.weight
#  |  0.001 | -0.035 |  0.038 |  0.015 || body.sub.14.res.0.bias
#  | -0.000 | -0.416 |  0.468 |  0.089 || body.sub.14.res.1.weight
#  |  0.007 | -0.077 |  0.100 |  0.032 || body.sub.14.res.1.bias
#  | -0.007 | -0.408 |  0.414 |  0.145 || body.sub.14.res.3.weight
#  |  0.000 | -0.026 |  0.019 |  0.007 || body.sub.14.res.3.bias
#  | -0.000 | -0.327 |  0.365 |  0.081 || body.sub.14.res.4.weight
#  |  0.000 | -0.032 |  0.039 |  0.010 || body.sub.14.res.4.bias
#  |  0.004 | -0.665 |  0.465 |  0.159 || body.sub.15.res.0.weight
#  |  0.001 | -0.034 |  0.032 |  0.013 || body.sub.15.res.0.bias
#  | -0.004 | -0.480 |  0.486 |  0.098 || body.sub.15.res.1.weight
#  |  0.005 | -0.057 |  0.054 |  0.026 || body.sub.15.res.1.bias
#  |  0.007 | -0.404 |  0.473 |  0.158 || body.sub.15.res.3.weight
#  |  0.000 | -0.015 |  0.022 |  0.008 || body.sub.15.res.3.bias
#  |  0.000 | -0.354 |  0.401 |  0.087 || body.sub.15.res.4.weight
#  |  0.001 | -0.026 |  0.041 |  0.010 || body.sub.15.res.4.bias
#  | -0.000 | -0.211 |  0.247 |  0.039 || body.sub.16.weight
#  | -0.004 | -0.058 |  0.063 |  0.027 || body.sub.16.bias
#  |  0.000 | -0.056 |  0.055 |  0.012 || tail.1.weight
#  | -0.000 | -0.018 |  0.029 |  0.010 || tail.1.bias
#  | -0.001 | -0.271 |  0.296 |  0.042 || tail.3.weight
#  |  0.034 | -0.018 |  0.092 |  0.026 || tail.3.bias
#  |  0.008 | -0.205 |  0.325 |  0.049 || tail.5.weight
#  | -0.000 | -0.069 |  0.073 |  0.018 || copress.weight
#  |  0.000 |  0.000 |  0.000 |  0.000 || copress.bias
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# 24-08-18 13:38:44.414 : <epoch:  0, iter:       3, Average PSNR : 11.60dB, Average SSIM : 0.2301
# 24-08-18 13:39:02.246 : <epoch:  1, iter:       6, Average PSNR : 11.91dB, Average SSIM : 0.2370
# 24-08-18 13:39:20.129 : <epoch:  2, iter:       9, Average PSNR : 11.94dB, Average SSIM : 0.2390
# 24-08-18 13:39:37.718 : <epoch:  3, iter:      12, Average PSNR : 11.72dB, Average SSIM : 0.2323
# 24-08-18 13:39:55.508 : <epoch:  4, iter:      15, Average PSNR : 11.95dB, Average SSIM : 0.2368
# 24-08-18 13:40:13.530 : <epoch:  5, iter:      18, Average PSNR : 12.54dB, Average SSIM : 0.2475
# 24-08-18 13:40:31.382 : <epoch:  6, iter:      21, Average PSNR : 12.89dB, Average SSIM : 0.2601
# 24-08-18 13:40:49.544 : <epoch:  7, iter:      24, Average PSNR : 13.29dB, Average SSIM : 0.2740
# 24-08-18 13:41:07.521 : <epoch:  8, iter:      27, Average PSNR : 13.66dB, Average SSIM : 0.2859
# 24-08-18 13:41:25.732 : <epoch:  9, iter:      30, Average PSNR : 13.92dB, Average SSIM : 0.2977
# 24-08-18 13:41:43.829 : <epoch: 10, iter:      33, Average PSNR : 14.38dB, Average SSIM : 0.3123
# 24-08-18 13:42:02.042 : <epoch: 11, iter:      36, Average PSNR : 15.05dB, Average SSIM : 0.3293
# 24-08-18 13:42:20.447 : <epoch: 12, iter:      39, Average PSNR : 15.50dB, Average SSIM : 0.3366
# 24-08-18 13:42:38.620 : <epoch: 13, iter:      42, Average PSNR : 15.93dB, Average SSIM : 0.3442
# 24-08-18 13:42:56.854 : <epoch: 14, iter:      45, Average PSNR : 16.71dB, Average SSIM : 0.3534
# 24-08-18 13:43:15.004 : <epoch: 15, iter:      48, Average PSNR : 17.25dB, Average SSIM : 0.3607
# 24-08-18 13:43:33.107 : <epoch: 16, iter:      51, Average PSNR : 17.56dB, Average SSIM : 0.3633
# 24-08-18 13:43:51.256 : <epoch: 17, iter:      54, Average PSNR : 18.17dB, Average SSIM : 0.3688
# 24-08-18 13:44:09.406 : <epoch: 18, iter:      57, Average PSNR : 18.63dB, Average SSIM : 0.3733
# 24-08-18 13:44:27.569 : <epoch: 19, iter:      60, Average PSNR : 18.59dB, Average SSIM : 0.3750
# 24-08-18 13:44:45.462 : <epoch: 20, iter:      63, Average PSNR : 19.02dB, Average SSIM : 0.3740
# 24-08-18 13:45:03.630 : <epoch: 21, iter:      66, Average PSNR : 19.44dB, Average SSIM : 0.3699
# 24-08-18 13:45:21.608 : <epoch: 22, iter:      69, Average PSNR : 19.74dB, Average SSIM : 0.3693
# 24-08-18 13:45:39.646 : <epoch: 23, iter:      72, Average PSNR : 19.97dB, Average SSIM : 0.3703
# 24-08-18 13:45:57.777 : <epoch: 24, iter:      75, Average PSNR : 20.29dB, Average SSIM : 0.3707
# 24-08-18 13:46:16.077 : <epoch: 25, iter:      78, Average PSNR : 20.62dB, Average SSIM : 0.3632
# 24-08-18 13:46:34.150 : <epoch: 26, iter:      81, Average PSNR : 20.71dB, Average SSIM : 0.3654
# 24-08-18 13:46:52.308 : <epoch: 27, iter:      84, Average PSNR : 20.72dB, Average SSIM : 0.3667
# 24-08-18 13:47:10.422 : <epoch: 28, iter:      87, Average PSNR : 20.11dB, Average SSIM : 0.3592
# 24-08-18 13:47:28.959 : <epoch: 29, iter:      90, Average PSNR : 20.62dB, Average SSIM : 0.3626
# 24-08-18 13:47:47.066 : <epoch: 30, iter:      93, Average PSNR : 20.90dB, Average SSIM : 0.3607
# 24-08-18 13:48:05.160 : <epoch: 31, iter:      96, Average PSNR : 20.90dB, Average SSIM : 0.3638
# 24-08-18 13:48:23.430 : <epoch: 32, iter:      99, Average PSNR : 20.87dB, Average SSIM : 0.3700
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:454: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# 24-08-18 13:48:25.009 : <epoch: 33, iter:     100, lr:1.000e-04> G_loss: 7.918e-04 F_loss: 3.306e-01 D_loss: 4.878e-02 l_d_real: 7.755e-05 l_d_fake: 1.140e-04 D_real: 4.149e+00 D_fake: -5.608e+00
# 24-08-18 13:48:41.576 : <epoch: 33, iter:     102, Average PSNR : 20.46dB, Average SSIM : 0.3644
# 24-08-18 13:48:59.784 : <epoch: 34, iter:     105, Average PSNR : 21.02dB, Average SSIM : 0.3678
# 24-08-18 13:49:18.014 : <epoch: 35, iter:     108, Average PSNR : 21.33dB, Average SSIM : 0.3683
# 24-08-18 13:49:36.106 : <epoch: 36, iter:     111, Average PSNR : 21.64dB, Average SSIM : 0.3677
# 24-08-18 13:49:54.229 : <epoch: 37, iter:     114, Average PSNR : 22.03dB, Average SSIM : 0.3725
# 24-08-18 13:50:12.256 : <epoch: 38, iter:     117, Average PSNR : 21.47dB, Average SSIM : 0.3700
# 24-08-18 13:50:30.635 : <epoch: 39, iter:     120, Average PSNR : 21.64dB, Average SSIM : 0.3742
# 24-08-18 13:50:48.883 : <epoch: 40, iter:     123, Average PSNR : 21.47dB, Average SSIM : 0.3700
# 24-08-18 13:51:07.088 : <epoch: 41, iter:     126, Average PSNR : 21.31dB, Average SSIM : 0.3618
# 24-08-18 13:51:25.197 : <epoch: 42, iter:     129, Average PSNR : 21.10dB, Average SSIM : 0.3675
# 24-08-18 13:51:43.550 : <epoch: 43, iter:     132, Average PSNR : 21.35dB, Average SSIM : 0.3723
# 24-08-18 13:52:01.447 : <epoch: 44, iter:     135, Average PSNR : 21.63dB, Average SSIM : 0.3658
# 24-08-18 13:52:19.515 : <epoch: 45, iter:     138, Average PSNR : 22.00dB, Average SSIM : 0.3693
# 24-08-18 13:52:37.851 : <epoch: 46, iter:     141, Average PSNR : 21.91dB, Average SSIM : 0.3729
# 24-08-18 13:52:55.761 : <epoch: 47, iter:     144, Average PSNR : 22.04dB, Average SSIM : 0.3777
# 24-08-18 13:53:13.775 : <epoch: 48, iter:     147, Average PSNR : 22.31dB, Average SSIM : 0.3773
# 24-08-18 13:53:32.107 : <epoch: 49, iter:     150, Average PSNR : 22.19dB, Average SSIM : 0.3784
# 24-08-18 13:53:50.186 : <epoch: 50, iter:     153, Average PSNR : 22.20dB, Average SSIM : 0.3815
# 24-08-18 13:54:08.309 : <epoch: 51, iter:     156, Average PSNR : 21.83dB, Average SSIM : 0.3748
# 24-08-18 13:54:26.420 : <epoch: 52, iter:     159, Average PSNR : 22.42dB, Average SSIM : 0.3812
# 24-08-18 13:54:44.610 : <epoch: 53, iter:     162, Average PSNR : 22.41dB, Average SSIM : 0.3762
# 24-08-18 13:55:02.777 : <epoch: 54, iter:     165, Average PSNR : 22.02dB, Average SSIM : 0.3782
# 24-08-18 13:55:21.074 : <epoch: 55, iter:     168, Average PSNR : 21.67dB, Average SSIM : 0.3722
# 24-08-18 13:55:39.124 : <epoch: 56, iter:     171, Average PSNR : 21.61dB, Average SSIM : 0.3730
# 24-08-18 13:55:57.172 : <epoch: 57, iter:     174, Average PSNR : 22.04dB, Average SSIM : 0.3757
# 24-08-18 13:56:15.455 : <epoch: 58, iter:     177, Average PSNR : 22.15dB, Average SSIM : 0.3723
# 24-08-18 13:56:33.899 : <epoch: 59, iter:     180, Average PSNR : 22.19dB, Average SSIM : 0.3760
# 24-08-18 13:56:52.162 : <epoch: 60, iter:     183, Average PSNR : 22.01dB, Average SSIM : 0.3697
# 24-08-18 13:57:10.543 : <epoch: 61, iter:     186, Average PSNR : 22.54dB, Average SSIM : 0.3772
# 24-08-18 13:57:28.902 : <epoch: 62, iter:     189, Average PSNR : 22.24dB, Average SSIM : 0.3700
# 24-08-18 13:57:47.287 : <epoch: 63, iter:     192, Average PSNR : 22.56dB, Average SSIM : 0.3743
# 24-08-18 13:58:05.820 : <epoch: 64, iter:     195, Average PSNR : 22.52dB, Average SSIM : 0.3797
# 24-08-18 13:58:24.494 : <epoch: 65, iter:     198, Average PSNR : 22.42dB, Average SSIM : 0.3787
# 24-08-18 13:58:26.101 : <epoch: 66, iter:     200, lr:1.000e-04> G_loss: 6.463e-04 F_loss: 3.068e-01 D_loss: 5.189e-02 l_d_real: 3.951e-05 l_d_fake: 6.831e-05 D_real: 4.361e+00 D_fake: -6.016e+00
# 24-08-18 13:58:42.782 : <epoch: 66, iter:     201, Average PSNR : 22.18dB, Average SSIM : 0.3861
# 24-08-18 13:59:00.870 : <epoch: 67, iter:     204, Average PSNR : 22.16dB, Average SSIM : 0.3860
# 24-08-18 13:59:18.943 : <epoch: 68, iter:     207, Average PSNR : 22.36dB, Average SSIM : 0.3804
# 24-08-18 13:59:37.047 : <epoch: 69, iter:     210, Average PSNR : 22.23dB, Average SSIM : 0.3787
# 24-08-18 13:59:55.236 : <epoch: 70, iter:     213, Average PSNR : 22.05dB, Average SSIM : 0.3758
# 24-08-18 14:00:13.680 : <epoch: 71, iter:     216, Average PSNR : 22.06dB, Average SSIM : 0.3845
# 24-08-18 14:00:32.261 : <epoch: 72, iter:     219, Average PSNR : 21.64dB, Average SSIM : 0.3754
# 24-08-18 14:00:50.558 : <epoch: 73, iter:     222, Average PSNR : 22.64dB, Average SSIM : 0.3824
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN/main_train_kdsrgan.py", line 264, in <module>
#     main()
#   File "/content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN/main_train_kdsrgan.py", line 239, in main
#     util.imsave(E_img, save_img_path)
#   File "/content/drive/MyDrive/Colab Notebooks/ISR/Infrared_Image_SR_PSRGAN/utilss/utils_image.py", line 206, in imsave
#     cv2.imwrite(img_path, img)
# KeyboardInterrupt
